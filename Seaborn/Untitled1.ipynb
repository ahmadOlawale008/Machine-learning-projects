# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style("darkgrid")

# %%
tips = sns.load_dataset("tips")
tips.tail(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.relplot(tips, x="tip", y="total_bill")

# %%
sns.relplot(tips, y="tip", x="total_bill", hue='size', style='time');
# tips['smoker'].value_counts()

# %%
sns.relplot(tips, y="tip", x="total_bill", hue='size', style='time', palette='ch:r=-0.5, l=.95');

# %%
sns.relplot(x="total_bill", y="tip", data=tips, size='size')

# %%
sns.relplot(x="total_bill", y="tip", data=tips, size='size', sizes=(15, 200))

# %%
df2 = pd.DataFrame(dict(time=np.arange(500), value=np.random.randn(500).cumsum()))
sns.relplot(df2, x="time", y='value', kind='line', sort=True)

# %%
df3 = pd.DataFrame(np.random.randn(500, 2).cumsum(axis=0), columns=['time', 'value'])
# sns.relplot(df3, x="time", y='value', kind='line', sort=False)

# %%
df4 = sns.load_dataset("fmri")
sns.relplot(df4, x='timepoint', y='signal', kind='line', errorbar=("ci", False))

# %%
sns.relplot(df4, x='timepoint', y='signal', kind='line', estimator=None)

# %%
sns.relplot(df4, x='timepoint', y='signal', hue='region', style='event', kind='line')

# %%
sns.relplot(df4, x='timepoint', y='signal', hue='region', style='event', kind='line', markers=True, dashes=False)

# %%
sns.relplot(df4.query("event == 'stim'"), x='timepoint', y='signal', hue='region', style='event', units='subject', estimator=None, kind='line')
plt.show()

# %%
dots = sns.load_dataset('dots').query('align=="dots"')
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(dots, x='time', y='firing_rate', kind='line', hue='coherence', style='choice');

# %%
palette = sns.cubehelix_palette(light=0.8, n_colors=6)
sns.relplot(dots, x='time', y='firing_rate', palette=palette, kind='line', hue='coherence', style='choice');

# %%
sns.relplot(dots, x='time', y='firing_rate', kind='line', hue='coherence', sizes=(1, 5), size='coherence', style='choice');

# %%
df5 = pd.DataFrame(dict(time=pd.date_range('2019-06-02', periods=500), value=np.random.randn(500).cumsum(axis=0)))

dfplot5=sns.relplot(df5, x='time', y='value', kind='line')
dfplot5.fig.autofmt_xdate()

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', col='time', data=tips);

# %%
sns.relplot(x='timepoint', y='signal', hue='smoker', col='size', data=tips);

# %%
sns.relplot(df4, x='timepoint', y='signal', hue='subject', col='region', col_wrap=1, kind='line', height=5)

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(df4,x='timepoint', y='signal');

# %%
titanic = sns.load_dataset('titanic')
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
sns.catplot(tips, hue='day', x='day', y='total_bill', jitter=False);

# %%
sns.catplot(tips, hue='day', x='day', y='total_bill', jitter=True);

# %%
sns.catplot(tips, hue='sex', x='day', y='total_bill', kind='swarm');

# %%
sns.catplot(tips, hue='sex', x='smoker', y='tip', kind='swarm', order=['No', "Yes"]);

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='sex', dodge=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
diamonds = sns.load_dataset('diamonds')
sns.catplot(x='color', y='price', kind='boxen', data=diamonds.sort_values("color"))

# %%
sns.violinplot(tips, x='total_bill', y='day', hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(tips, x='total_bill', y='day', inner='stick', hue='sex', split=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
v = sns.catplot(tips, kind='violin', x='day', y='total_bill', inner=None, hue='sex', split=True)
sns.swarmplot(x='day', y='total_bill', color='k', size=3, data= tips, ax=v.ax)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='sex', y='survived', kind='bar', hue='class', data=titanic)

# %%
sns.catplot(x='deck', kind='count', palette='ch:-12.95', data=titanic)

# %%
sns.catplot(x='deck', kind='count', hue='survived', palette='ch:-12.95', data=titanic)

# %%
sns.catplot(x='sex', y='survived', kind='point', hue='class', palette='ch:-12.95', data=titanic)

# %%
x = np.random.randn(100)
sns.histplot(x, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(x, kde=False, bins=30)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.distplot(x,  bins=30, hist=False)
# Out:
# C:\Users\Ahmad Kazeem\AppData\Local\Temp\ipykernel_25724\3998361434.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x,  bins=30, hist=False)
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(x, fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(x, fill=True, bw_method=0.2) #band with
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(x, fill=True, cut=0) #band with
# Out:
# <Axes: ylabel='Density'>

# %%
sns.jointplot(x=tips['total_bill'], y=tips['tip'])

# %%
# sns.set_style("darkgrid")
sns.jointplot(x=tips['total_bill'], y=tips['tip'], kind='hex')

# %%
sns.jointplot(x=tips['total_bill'], fill=True, y=tips['tip'], kind='kde')

# %%
f, ax = plt.subplots(figsize=(6,6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(x=tips['total_bill'], y=tips['tip'], cmap=cmap, n_levels=60, fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
g = sns.jointplot(x=tips['total_bill'], kind='kde', y=tips['tip'],  fill=True)
