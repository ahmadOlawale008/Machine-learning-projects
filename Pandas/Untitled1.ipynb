# %%
import pandas as pd

# %%
df = pd.read_excel("SELECTED FOOD AUGUST 2022.xlsx", index_col=0)
df
# Out:
#                                            Average of Aug-21  \
# Items
# Agric eggs medium size                            585.635586
# Agric eggs(medium size price of one)               53.201042
# Beans brown,sold loose                            496.029171
# Beans:white black eye. sold loose                 457.976534
# Beef Bone in                                     1274.198234
# Beef,boneless                                    1700.884966
# Bread sliced 500g                                 366.687420
# Bread unsliced 500g                               342.776484
# Broken Rice (Ofada)                               477.387389
# Catfish (obokun) fresh                           1204.600456
# Catfish :dried                                   1868.948624
# Catfish Smoked                                   1603.894861
# Chicken Feet                                      830.169525
# Chicken Wings                                    1109.632639
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43 entries, Agric eggs medium size to Yam tuber
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Average of Aug-21  43 non-null     float64
#  1   Average of Jul-22  43 non-null     float64
#  2   Average of Aug-22  43 non-null     float64
#  3   MoM                43 non-null     float64
#  4   YoY                43 non-null     float64
#  5   Lowest             43 non-null     object
#  6   Highest            43 non-null     object
#  7   Unnamed: 8         0 non-null      float64
#  8   Unnamed: 9         0 non-null      float64
#  9   Items.1            10 non-null     object
#  10  NORTH CENTRAL      10 non-null     float64
#  11  NORTH EAST         10 non-null     float64
#  12  NORTH WEST         10 non-null     float64
#  13  SOUTH EAST         10 non-null     float64
#  14  SOUTH SOUTH        10 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Average of Aug-21  Average of Jul-22  Average of Aug-22        MoM  \
# count          43.000000          43.000000          43.000000  43.000000
# mean          759.989301         905.386067         910.207259   0.269348
# std           545.965068         641.502553         648.986753   2.642504
# min            53.201042          71.036735          73.318477  -5.507612
# 25%           329.706240         393.356323         417.277491  -0.541022
# 50%           496.029171         562.554078         545.614821   0.689394
# 75%          1185.479163        1374.241992        1390.433264   1.294010
# max          2091.336106        2488.830883        2531.522168   9.678811
#
#              YoY  Unnamed: 8  Unnamed: 9  NORTH CENTRAL   NORTH EAST  \
# count  43.000000         0.0         0.0      10.000000    10.000000
# mean   20.493780         NaN         NaN     551.307229   529.348388
# std    10.376684         NaN         NaN     478.732700   432.426571
# ...

# %%
df.columns
# Out:
# Index(['Average of Aug-21', 'Average of Jul-22', 'Average of Aug-22', 'MoM',
#        'YoY', 'Lowest', 'Highest', 'Unnamed: 8', 'Unnamed: 9', 'Items.1',
#        'NORTH CENTRAL', 'NORTH EAST', 'NORTH WEST', 'SOUTH EAST',
#        'SOUTH SOUTH', 'SOUTH WEST'],
#       dtype='object')

# %%
df.shape
# Out:
# (43, 16)

# %%
df[['Average of Aug-21', 'Average of Jul-22']]
# Out:
#                                            Average of Aug-21  \
# Items
# Agric eggs medium size                            585.635586
# Agric eggs(medium size price of one)               53.201042
# Beans brown,sold loose                            496.029171
# Beans:white black eye. sold loose                 457.976534
# Beef Bone in                                     1274.198234
# Beef,boneless                                    1700.884966
# Bread sliced 500g                                 366.687420
# Bread unsliced 500g                               342.776484
# Broken Rice (Ofada)                               477.387389
# Catfish (obokun) fresh                           1204.600456
# Catfish :dried                                   1868.948624
# Catfish Smoked                                   1603.894861
# Chicken Feet                                      830.169525
# Chicken Wings                                    1109.632639
# ...

# %%
df['Average of Aug-21'].first_valid_index()
# Out:
# 'Agric eggs medium size'

# %%
df.loc["Tomato"]
# Out:
# Average of Aug-21       396.383131
# Average of Jul-22       446.812084
# Average of Aug-22       430.927836
# MoM                      -3.555018
# YoY                       8.714979
# Lowest               Abuja (50.75)
# Highest               Edo (799.31)
# Unnamed: 8                     NaN
# Unnamed: 9                     NaN
# Items.1                        NaN
# NORTH CENTRAL                  NaN
# NORTH EAST                     NaN
# NORTH WEST                     NaN
# SOUTH EAST                     NaN
# SOUTH SOUTH                    NaN
# SOUTH WEST                     NaN
# Name: Tomato, dtype: object

# %%
df.at["Agric eggs medium size", "NORTH EAST"]
# Out:
# 377.3730431502842

# %%
df.tail(3)
df.head(5)
# Out:
#                                       Average of Aug-21  Average of Jul-22  \
# Items
# Agric eggs medium size                       585.635586         721.464544
# Agric eggs(medium size price of one)          53.201042          71.036735
# Beans brown,sold loose                       496.029171         562.554078
# Beans:white black eye. sold loose            457.976534         547.378542
# Beef Bone in                                1274.198234        1589.178419
#
#                                       Average of Aug-22       MoM        YoY  \
# Items
# Agric eggs medium size                       733.582059  1.679572  25.262549
# Agric eggs(medium size price of one)          73.318477  3.212059  37.813985
# Beans brown,sold loose                       545.614821 -3.011134   9.996519
# Beans:white black eye. sold loose            517.231057 -5.507612  12.938332
# Beef Bone in                                1610.311681  1.329823  26.378427
#
# ...

# %%
df.sample(12)
# Out:
#                                            Average of Aug-21  \
# Items
# Beans brown,sold loose                            496.029171
# Rice,imported high quality sold loose             546.707474
# Tilapia fish (epiya) fresh                       1051.631007
# Catfish (obokun) fresh                           1204.600456
# Bread sliced 500g                                 366.687420
# Beef,boneless                                    1700.884966
# Rice local sold loose                             409.965768
# Plantain(ripe)                                    290.961942
# Wheat flour: prepacked (golden penny 2kg)         869.635519
# Sweet potato                                      195.870441
# Broken Rice (Ofada)                               477.387389
# Onion bulb                                        302.877235
#
#                                            Average of Jul-22  \
# Items
# Beans brown,sold loose                            562.554078
# ...

# %%
total_cases = df["Average of Jul-22"].sum()
total_cases
# Out:
# 38931.60088079632

# %%
highests = df[df["Average of Jul-22"] > 200]
highests
# Out:
#                                            Average of Aug-21  \
# Items
# Agric eggs medium size                            585.635586
# Beans brown,sold loose                            496.029171
# Beans:white black eye. sold loose                 457.976534
# Beef Bone in                                     1274.198234
# Beef,boneless                                    1700.884966
# Bread sliced 500g                                 366.687420
# Bread unsliced 500g                               342.776484
# Broken Rice (Ofada)                               477.387389
# Catfish (obokun) fresh                           1204.600456
# Catfish :dried                                   1868.948624
# Catfish Smoked                                   1603.894861
# Chicken Feet                                      830.169525
# Chicken Wings                                    1109.632639
# Dried Fish Sardine                               1593.154230
# ...

# %%
from IPython.display import display
with pd.option_context("display.max_rows", 1000):
    display(df[df["Average of Jul-22"] > 200])
# Out:
#                                            Average of Aug-21  \
# Items
# Agric eggs medium size                            585.635586
# Beans brown,sold loose                            496.029171
# Beans:white black eye. sold loose                 457.976534
# Beef Bone in                                     1274.198234
# Beef,boneless                                    1700.884966
# Bread sliced 500g                                 366.687420
# Bread unsliced 500g                               342.776484
# Broken Rice (Ofada)                               477.387389
# Catfish (obokun) fresh                           1204.600456
# Catfish :dried                                   1868.948624
# Catfish Smoked                                   1603.894861
# Chicken Feet                                      830.169525
# Chicken Wings                                    1109.632639
# Dried Fish Sardine                               1593.154230
# ...

# %%
df.drop(columns=['YoY'], inplace=False)
# Out:
#                                            Average of Aug-21  \
# Items
# Agric eggs medium size                            585.635586
# Agric eggs(medium size price of one)               53.201042
# Beans brown,sold loose                            496.029171
# Beans:white black eye. sold loose                 457.976534
# Beef Bone in                                     1274.198234
# Beef,boneless                                    1700.884966
# Bread sliced 500g                                 366.687420
# Bread unsliced 500g                               342.776484
# Broken Rice (Ofada)                               477.387389
# Catfish (obokun) fresh                           1204.600456
# Catfish :dried                                   1868.948624
# Catfish Smoked                                   1603.894861
# Chicken Feet                                      830.169525
# Chicken Wings                                    1109.632639
# ...

# %%
df.sort_values('Items', ascending=True)
# Out:
#                                            Average of Aug-21  \
# Items
# Agric eggs medium size                            585.635586
# Agric eggs(medium size price of one)               53.201042
# Beans brown,sold loose                            496.029171
# Beans:white black eye. sold loose                 457.976534
# Beef Bone in                                     1274.198234
# Beef,boneless                                    1700.884966
# Bread sliced 500g                                 366.687420
# Bread unsliced 500g                               342.776484
# Broken Rice (Ofada)                               477.387389
# Catfish (obokun) fresh                           1204.600456
# Catfish :dried                                   1868.948624
# Catfish Smoked                                   1603.894861
# Chicken Feet                                      830.169525
# Chicken Wings                                    1109.632639
# ...

# %%
df2 = pd.read_csv("Book DIS.csv")
df2.Dates = pd.to_datetime(df2.Dates)
df2['Year'] = pd.DatetimeIndex(df2.Dates).year
df2['Month'] = pd.DatetimeIndex(df2.Dates).month
df2['day'] = pd.DatetimeIndex(df2.Dates).day
df2['weekday'] = pd.DatetimeIndex(df2.Dates).weekday
df2
# Out:
#         Dates  Diseases of heart  Ischemic heart disease  \
# 0  1989-03-01              332.0                   257.5
# 1  1990-03-01              321.8                   249.6
# 2  1991-03-01              312.5                   240.6
# 3  1992-03-01              304.0                   232.6
# 4  1993-03-01              308.1                   233.2
# 5  1994-03-01              297.5                   224.5
# 6  1995-03-01              293.4                   219.7
# 7  1996-03-01              285.7                   212.1
# 8  1997-03-01              277.7                   203.6
# 9  1998-03-01              271.3                   197.1
# 10 1999-04-01              266.5                   194.6
# 11 2000-04-01              257.6                   186.8
# 12 2001-04-01              249.5                   179.0
# 13 2002-04-01              244.6                   173.5
# 14 2003-04-01              236.3                   165.6
# ...

# %%
group = df.groupby("MoM")
group[df.columns].cumsum()
# Out:
# C:\Users\Ahmad Kazeem\AppData\Local\Temp\ipykernel_8484\3898764825.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group[df.columns].cumsum()
#                                            Average of Aug-21  \
# Items
# Agric eggs medium size                            585.635586
# Agric eggs(medium size price of one)               53.201042
# Beans brown,sold loose                            496.029171
# Beans:white black eye. sold loose                 457.976534
# Beef Bone in                                     1274.198234
# Beef,boneless                                    1700.884966
# Bread sliced 500g                                 366.687420
# Bread unsliced 500g                               342.776484
# Broken Rice (Ofada)                               477.387389
# ...

# %%
inflation = pd.read_excel("Inflation sample.xlsx", usecols="A:B")
inflation
# Out:
#      Month  Inflation (%)
# 0        1           21.3
# 1        2           23.8
# 2        3           22.4
# 3        4           24.8
# 4        5           22.5
# ..     ...            ...
# 115    116            8.4
# 116    117            8.7
# 117    118            8.2
# 118    119            8.0
# 119    120            7.8
#
# [120 rows x 2 columns]

# %%
merge_df = df2.merge(inflation, on="Month")
merge_df
# Out:
#         Dates  Diseases of heart  Ischemic heart disease  \
# 0  1989-03-01              332.0                   257.5
# 1  1990-03-01              321.8                   249.6
# 2  1991-03-01              312.5                   240.6
# 3  1992-03-01              304.0                   232.6
# 4  1993-03-01              308.1                   233.2
# 5  1994-03-01              297.5                   224.5
# 6  1995-03-01              293.4                   219.7
# 7  1996-03-01              285.7                   212.1
# 8  1997-03-01              277.7                   203.6
# 9  1998-03-01              271.3                   197.1
# 10 1999-04-01              266.5                   194.6
# 11 2000-04-01              257.6                   186.8
# 12 2001-04-01              249.5                   179.0
# 13 2002-04-01              244.6                   173.5
# 14 2003-04-01              236.3                   165.6
# ...

# %%
merge_df.to_csv("merged.csv", index=None)

# %%
import numpy as np
inflation['Inflation (%)'].plot()
np.sin(inflation['Inflation (%)'])
# Out:
# Month
# 1      0.637423
# 2     -0.971798
# 3     -0.397556
# 4     -0.326635
# 5     -0.487175
#          ...
# 116    0.854599
# 117    0.662969
# 118    0.940731
# 119    0.989358
# 120    0.998543
# Name: Inflation (%), Length: 120, dtype: float64
